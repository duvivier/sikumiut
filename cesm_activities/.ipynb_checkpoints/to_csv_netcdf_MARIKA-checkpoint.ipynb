# %% [markdown]
# # Convert files to csv
#
# * **Description**: Reads in and creates csv from netcdf files
# * **Creator**: Alice DuVivier
# * **Date**: March 2025

# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
from datetime import timedelta

# %% [markdown]
# ## Load data

# %%
data_dir = '/glade/campaign/cgd/ppc/duvivier/sikumiut/DATA/'

# %%
fin = 'LE2_aicetot_nh_1870-2100'

# %%
ds_in = xr.open_mfdataset(data_dir + fin+'.nc')

# %%
ds_in
# Out:
# <xarray.Dataset> Size: 555kB
# Dimensions:       (nyr: 231, n_members: 50, nmonth: 12)
# Dimensions without coordinates: nyr, n_members, nmonth
# Data variables:
#     year          (nyr) float32 924B dask.array<chunksize=(231,), meta=np.ndarray>
#     aice_monthly  (n_members, nyr, nmonth) float32 554kB dask.array<chunksize=(50, 231, 12), meta=np.ndarray>

# %% [markdown]
# ## Keep Septembers only

# %%
ds_sept = ds_in.aice_monthly.isel(nmonth=8)

# %%
ds_sept
# Out:
# <xarray.DataArray 'aice_monthly' (n_members: 50, nyr: 231)> Size: 46kB
# dask.array<getitem, shape=(50, 231), dtype=float32, chunksize=(50, 231), chunktype=numpy.ndarray>
# Dimensions without coordinates: n_members, nyr

# %%
ds_sept = ds_in.aice_monthly.isel(nmonth=8)

# %%
ds_sept.plot()

# %%
years = ds_sept.nyr

# %%
years
# Out:
# <xarray.DataArray 'nyr' (nyr: 231)> Size: 2kB
# array([  0,   1,   2, ..., 228, 229, 230])
# Dimensions without coordinates: nyr

# %% [markdown]
# ## Save the timeseries

# %%
# convert to dataframe
df = ds_sept.to_dataframe()

# %%
fout = fin

# %%
df.to_csv(fout+'.csv')
